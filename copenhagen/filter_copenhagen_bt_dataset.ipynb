# %%
# add bt_symmetric.csv to notebook files
import pandas as pd

es = pd.read_csv('bt_symmetric.csv')

es = es.drop(columns=['rssi'])
is_detected = es['user_b'] != -1
is_internal = es['user_b'] != -2
es = es[is_detected]
es = es[is_internal]
es = es[['user_a','user_b','# timestamp']]
es.columns = ['s','t','time']

es.head()

es.to_csv('bt-detected-internal.csv', index=False, header=False)

es = es.drop(columns=['time'])
es.to_csv('bt-detected-internal-notime.csv', index=False, header=False)

#import networkx as nx
#import matplotlib.pyplot as plt

#G = nx.readwrite.edgelist.read_edgelist('bt-detected-internal-notime.csv', delimiter=',')

#print(G.number_of_nodes())
#print(G.number_of_edges())

# nx.draw(G, pos=nx.spring_layout(G))
#nx.draw(G, pos=nx.fruchterman_reingold_layout(G))
#plt.draw()
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:10: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#   # Remove the CWD from sys.path while we load stuff.
# 692
# 79530
